# %% [markdown]
# # Pancake Pridiction v2

# %%
from web3 import Web3
from web3.middleware import geth_poa_middleware
import datetime as dt
import pandas as pd
import numpy as np
import math
import random
import statsmodels.api as sm

pd.set_option('display.max_rows', None)

# %%
import os
import sys

current_dir = os.getcwd()
project_dir = os.path.dirname(current_dir)
sys.path.append(project_dir) if project_dir not in sys.path else None

import pancake
psp = pancake.Prediction()

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Config

# %%
dataset_reconds = 300

# %% [markdown]
# ### Fetching Data

# %%
round_columns = ["epoch",
                 "startTimestamp",
                 "lockTimestamp",
                 "closeTimestamp",
                 "lockPrice",
                 "closePrice",
                 "lockOracleId",
                 "closeOracleId",
                 "totalAmount",
                 "bullAmount",
                 "bearAmount",
                 "rewardBaseCalAmount",
                 "rewardAmount",
                 "oracleCalled"]

def get_history(_psp, current_epoch, back_in_time=100):
    start_epoch_history = current_epoch - 2 - back_in_time

    df_history_round = pd.DataFrame(columns=round_columns)
    for i in range(start_epoch_history, current_epoch - 1):
        df_round = _psp.get_round(i)
        df_history_round = df_history_round.append(df_round)

    df_history_round = df_history_round.sort_values('epoch', ascending=False)
    df_history_round = df_history_round.reset_index(drop=True)
    
    return df_history_round

# %% [markdown]
# #### Creating a dataset

# %%
current_epoch = psp.get_current_epoch()
df = get_history(psp, current_epoch, dataset_reconds)
df.head()
# Out:
#      epoch  startTimestamp  lockTimestamp  closeTimestamp   lockPrice  \
# 0  43033.0    1.644210e+09   1.644211e+09    1.644211e+09  427.820892
# 1  43032.0    1.644210e+09   1.644210e+09    1.644211e+09  427.548462
# 2  43031.0    1.644210e+09   1.644210e+09    1.644210e+09  428.689667
# 3  43030.0    1.644210e+09   1.644210e+09    1.644210e+09  427.656219
# 4  43029.0    1.644209e+09   1.644210e+09    1.644210e+09  426.844360
#
#    closePrice  lockOracleId  closeOracleId  totalAmount  bullAmount  \
# 0  428.453949           0.0            0.0    24.919741   16.931665
# 1  427.820892           0.0            0.0    27.014004   15.376600
# 2  427.548462           0.0            0.0    45.461021   30.665218
# 3  428.689667           0.0            0.0    25.973127   13.984817
# 4  427.656219           0.0            0.0    20.815071   10.964463
#
#    bearAmount  rewardBaseCalAmount  rewardAmount oracleCalled
# 0    7.988076            16.931665     24.172148         True
# 1   11.637403            15.376600     26.203583         True
# 2   14.795802            14.795802     44.097191         True
# 3   11.988310            13.984817     25.193933         True
# 4    9.850608            10.964463     20.190619         True

# %% [markdown]
# ### Adding result

# %%
def add_result(lockPrice, closePrice):
    if lockPrice == closePrice:
        # draw
        return 0
    elif lockPrice > closePrice:
        # bear
        return -1
    elif lockPrice < closePrice:
        # bull
        return 1
        
df["result"] = df.apply(lambda row : add_result(row["lockPrice"], row["closePrice"]), axis=1)
df.head()
# Out:
#      epoch  startTimestamp  lockTimestamp  closeTimestamp   lockPrice  \
# 0  43033.0    1.644210e+09   1.644211e+09    1.644211e+09  427.820892
# 1  43032.0    1.644210e+09   1.644210e+09    1.644211e+09  427.548462
# 2  43031.0    1.644210e+09   1.644210e+09    1.644210e+09  428.689667
# 3  43030.0    1.644210e+09   1.644210e+09    1.644210e+09  427.656219
# 4  43029.0    1.644209e+09   1.644210e+09    1.644210e+09  426.844360
#
#    closePrice  lockOracleId  closeOracleId  totalAmount  bullAmount  \
# 0  428.453949           0.0            0.0    24.919741   16.931665
# 1  427.820892           0.0            0.0    27.014004   15.376600
# 2  427.548462           0.0            0.0    45.461021   30.665218
# 3  428.689667           0.0            0.0    25.973127   13.984817
# 4  427.656219           0.0            0.0    20.815071   10.964463
#
#    bearAmount  rewardBaseCalAmount  rewardAmount oracleCalled  result
# 0    7.988076            16.931665     24.172148         True       1
# 1   11.637403            15.376600     26.203583         True       1
# 2   14.795802            14.795802     44.097191         True      -1
# 3   11.988310            13.984817     25.193933         True       1
# 4    9.850608            10.964463     20.190619         True       1

# %% [markdown]
# ### Maximum Consecutive Occurance

# %%
countDf = pd.DataFrame({'result': list(df['result'][(df['result'])
                       .diff().abs().fillna(1) > 0]),
                     'runs': list(df['result'].groupby((df['result'])
                       .diff().abs().fillna(1).cumsum()).count())})

bear_count = countDf[countDf.result == -1]['runs'].max()
bull_count = countDf[countDf.result == 1]['runs'].max()
draw_count = countDf[countDf.result == 0]['runs'].max()

print(f"Bear {bear_count} / Bull {bull_count} / Draw {draw_count}")
# Out:
# Bear 7 / Bull 7 / Draw nan

# %% [markdown]
# ## Strategies

# %%
running_columns = ["epoch", "position", "amount", "reward", "recent_loss", "factor"]
df_running = pd.DataFrame(columns=running_columns)

# %%
def get_partial_history(df, current_epoch, back_in_time=6):
    df_history_round = df[(df.epoch < current_epoch) & (df.epoch >= current_epoch - back_in_time)]
    return df_history_round

    
def bet(df_running, epoch, position, amount, recent_loss, factor):
    data = [epoch, position, amount, 0, recent_loss, factor]
    temp = pd.DataFrame(data=[data], columns=running_columns)
    df_running = df_running.append(temp)
    return df_running

    
def get_round_stats(df, epoch):
    df_round = df[df.epoch == epoch]

    total_amount = (df_round["bullAmount"] + df_round["bearAmount"]).iloc[0]
    if total_amount > 0:
        bull_ratio = ((df_round["bullAmount"] / total_amount) * 100).iloc[0]
        bear_ratio = ((df_round["bearAmount"] / total_amount) * 100).iloc[0]
        bear_pay_ratio = (total_amount / df_round["bearAmount"]).iloc[0]
        bull_pay_ratio = (total_amount / df_round["bullAmount"]).iloc[0]
    else:
        bull_ratio = None
        bear_ratio = None
        bear_pay_ratio = None
        bull_pay_ratio = None

    lockPrice = df_round["lockPrice"].iloc[0]
    closePrice = df_round["closePrice"].iloc[0]

    if lockPrice == closePrice:
        # draw
        result = 0
    elif lockPrice > closePrice:
        # bear
        result = -1
    elif lockPrice < closePrice:
        # bull
        result = 1
    
    return {"total_amount": total_amount,
           "bull_ratio": bull_ratio, "bear_ratio": bear_ratio,
           "bear_pay_ratio": bear_pay_ratio, "bull_pay_ratio": bull_pay_ratio,
           "result": result}


def update_reward(df, df_running, epoch, status):
    bet_value = df_running[df_running.epoch == epoch]["amount"].iloc[0]
    bet_position = df_running[df_running.epoch == epoch]["position"].iloc[0]
    
    if status == 0:
        df_running.loc[df_running.epoch == epoch, "reward"] = -1 * bet_value
        pay_ratio = 0
    elif status == 1:
        epoch_stats = get_round_stats(df, epoch)
        if bet_position == "bull":
            pay_ratio = epoch_stats["bull_pay_ratio"]
        elif bet_position == "bear":
            pay_ratio = epoch_stats["bear_pay_ratio"]

        df_running.loc[df_running.epoch == epoch, "reward"] = (bet_value * pay_ratio) - bet_value
    
    print(f"[{epoch}] - Factor {pay_ratio} - Bet {bet_value} - Position {position}")    
    return df_running


def check_result(df, df_running, epoch):
    
    bet_position = df_running[df_running.epoch == epoch]["position"].iloc[0]
    epoch_stats = get_round_stats(df, epoch)
    
    if bet_position == "bull" and epoch_stats["result"] == 1:
        result = 1
    elif bet_position == "bear" and epoch_stats["result"] == -1:
        result = 1
    else:
        result = 0
    
    df_running = update_reward(df, df_running, epoch, result)
    return df_running, epoch_stats["result"]
    

def overview(df_running):
    total_spent = df_running.sum()["amount"]
    total_loss = abs(df_running[df_running["reward"] < 0].sum()["reward"])
    loss_times = df_running[df_running["reward"] < 0].count()["reward"]
    estimated_win = df_running[df_running["reward"] > 0].sum()["reward"]
    win_times = df_running[df_running["reward"] > 0].count()["reward"]
    estimated_gain = df_running.sum()["reward"]
    max_spent = df_running.max()["amount"]

    last_win_epoch = df_running[df_running["reward"] > 0].max()["epoch"]
    if last_win_epoch is None or math.isnan(last_win_epoch):
        recent_loss = abs(df_running.sum()["reward"])
        recent_loss_times = df_running[df_running["reward"] < 0].count()["reward"]
    else:
        recent_loss = abs(df_running[df_running["epoch"] > last_win_epoch].sum()["reward"])
        recent_loss_times = df_running[(df_running["epoch"] > last_win_epoch)
                                       & (df_running["reward"] < 0)].count()["reward"]

    return {"total_spent": total_spent,
            "max_spent": max_spent,
            "total_loss": total_loss,
            "loss_times": loss_times,
            "estimated_win": estimated_win,
            "win_times": win_times,
            "estimated_gain": estimated_gain,
            "recent_loss": recent_loss,
            "recent_loss_times": recent_loss_times}

# %% [markdown]
# ### Strategies Default Settings

# %%
starting_epoch = df.min()["epoch"] + 20
maximum_epoch = df.max()["epoch"] - 1

# 0: Even / 1: Odd
strategy_remainder = 0
base_bet = 0.01
safe_bet = 0.2

current_epoch = starting_epoch
value = base_bet
print("Starting Epoch: ", starting_epoch)
# Out:
# Starting Epoch:  42753.0

# %% [markdown]
# ### Strategy 1: Trend

# %%
def calculate_trend(df, current_epoch, back_in_time=6):
    df_history_round = get_partial_history(df, current_epoch, back_in_time)
    X = df_history_round.index
    X = X.astype(float)

    y = df_history_round['closePrice']
    y = y.astype(float)

    X = sm.add_constant(X)
    model = sm.OLS(y, X).fit()

    alpha = model.params['x1']
    return alpha

# %% [raw]
# while current_epoch < maximum_epoch:
#     if current_epoch % 2 == strategy_remainder:
#
#         bet_status = overview(df_running)
#         current_round_stats = get_round_stats(df, current_epoch)
#
#         trend = calculate_trend(df, current_epoch, 3)
#         print("Trend: ", trend)
#
#         if trend < 0:
#             # bull
#             custom_factor = current_round_stats["bull_pay_ratio"] - safe_bet
#             position = "bull"
#         else:
#             # bear
#             custom_factor = current_round_stats["bear_pay_ratio"] - safe_bet
#             position = "bear"
#
#         value = (bet_status["recent_loss"] + base_bet) / (custom_factor - 1)
#         if value < base_bet:
#             value = base_bet
#
#         df_running = bet(df_running, current_epoch, position, value, bet_status["recent_loss"], custom_factor)
#         df_running, result = check_result(df, df_running, current_epoch)
#         print(f"[{current_epoch}] - {position} - {value}")
#     current_epoch += 1

# %% [markdown]
# ### Strategy 2: Same-Before

# %% [raw]
# while current_epoch < maximum_epoch:
#     if current_epoch % 2 == strategy_remainder:
#
#         bet_status = overview(df_running)
#         current_round_stats = get_round_stats(df, current_epoch)
#
#         data = df[df.epoch == current_epoch - 2]
#         lock_price = data["lockPrice"].iloc[0]
#         close_price = data["closePrice"].iloc[0]
#
#         if lock_price < close_price:
#             # bull
#             position = "bull"
#             custom_factor = current_round_stats["bull_pay_ratio"] - safe_bet
#         else:
#             # bear
#             position = "bear"
#             custom_factor = current_round_stats["bear_pay_ratio"] - safe_bet
#
#         value = (bet_status["recent_loss"] + base_bet) / (custom_factor - 1)
#         if value < base_bet:
#             value = base_bet
#
#         df_running = bet(df_running, current_epoch, position, value, bet_status["recent_loss"], custom_factor)
#         df_running, result = check_result(df, df_running, current_epoch)
#         print(f"[{current_epoch}] - {position} - {value}")
#     current_epoch += 1

# %% [markdown]
# ### Strategy 3: Random

# %% [raw]
# while current_epoch < maximum_epoch:
#     if current_epoch % 2 == strategy_remainder:
#
#         bet_status = overview(df_running)
#         current_round_stats = get_round_stats(df, current_epoch)
#
#         rand = random.getrandbits(1)
#
#         if rand:
#             # bull
#             custom_factor = current_round_stats["bull_pay_ratio"] - safe_bet
#             position = "bull"
#         else:
#             # bear
#             custom_factor = current_round_stats["bear_pay_ratio"] - safe_bet
#             position = "bear"
#
#         value = (bet_status["recent_loss"] + base_bet) / (custom_factor - 1)
#         if value < base_bet:
#             value = base_bet
#
#         df_running = bet(df_running, current_epoch, position, value, bet_status["recent_loss"], custom_factor)
#         df_running, result = check_result(df, df_running, current_epoch)
#         print(f"[{current_epoch}] - {position} - {value}")
#     current_epoch += 1

# %% [markdown]
# ### Strategy 4: Exponential Moving Average (EMA)

# %%
def calculate_ema(prices, days, smoothing=2):
    ema = [sum(prices[:days]) / days]
    for price in prices[days:]:
        ema.append((price * (smoothing / (1 + days))) + ema[-1] * (1 - (smoothing / (1 + days))))
    return ema

# %%
while current_epoch < maximum_epoch:
    if current_epoch % 2 == strategy_remainder:

        bet_status = overview(df_running)
        current_round_stats = get_round_stats(df, current_epoch)

        df_history_round = get_partial_history(df, current_epoch, back_in_time=21)

        currentPrice = np.round(df_history_round["closePrice"].iloc[0],1)
        ema9 = np.round(calculate_ema(df_history_round["closePrice"].iloc[:9],9),1)
        ema21 = np.round(calculate_ema(df_history_round["closePrice"].iloc[:21],21),1)

        print('current price:', currentPrice)
        print('ema9 :', ema9, ' ema21:',ema21)
            
        if (ema9 == ema21):
            print('do nothing')
            position = "skip"

        elif (ema9 < ema21):
            custom_factor = current_round_stats["bear_pay_ratio"] - safe_bet
            position = "bear"
            if(currentPrice > ema9):
                print('bet bearish , confidence 100')
            else :
                print('bet bearish , confidence enough')

        elif (ema9 > ema21):
            custom_factor = current_round_stats["bull_pay_ratio"] - safe_bet
            position = "bull"
            if(currentPrice < ema9):
                print('bet bullish , confidence 100')
            else :
                print('bet bullish , confidence enough')
        
        value = (bet_status["recent_loss"] + base_bet) / (custom_factor - 1)
        if value < base_bet:
            value = base_bet
            
        if position == "bull" or position == "bear":
            df_running = bet(df_running, current_epoch, position, value, bet_status["recent_loss"], custom_factor)
            df_running, result = check_result(df, df_running, current_epoch)
        elif position == "skip":
            print(f"[{current_epoch}] - Skipped.")
            
    current_epoch += 1
# Out:
# current price: 415.4
# ema9 : [415.1]  ema21: [416.]
# bet bearish , confidence 100
# [42754.0] - Factor 0 - Bet 0.014678302677070265 - Position bear
# current price: 415.4
# ema9 : [415.2]  ema21: [415.7]
# bet bearish , confidence 100
# [42756.0] - Factor 0 - Bet 0.03084932177518762 - Position bear
# current price: 415.8
# ema9 : [415.4]  ema21: [415.4]
# do nothing
# [42758.0] - Skipped.
# current price: 416.1
# ema9 : [415.5]  ema21: [415.2]
# bet bullish , confidence enough
# [42760.0] - Factor 0 - Bet 0.055277861485960575 - Position bull
# current price: 415.6
# ema9 : [415.6]  ema21: [415.1]
# bet bullish , confidence enough
# [42762.0] - Factor 2.083345413208008 - Bet 0.12543845734797093 - Position bull
# current price: 415.1
# ema9 : [415.6]  ema21: [415.2]
# bet bullish , confidence 100
# [42764.0] - Factor 0 - Bet 0.013181495439435717 - Position bull
# current price: 413.7
# ema9 : [415.2]  ema21: [415.2]
# do nothing
# [42766.0] - Skipped.
# current price: 414.7
# ema9 : [414.9]  ema21: [415.1]
# bet bearish , confidence enough
# [42768.0] - Factor 0 - Bet 0.02307161781013631 - Position bear
# current price: 414.6
# ema9 : [414.7]  ema21: [415.1]
# bet bearish , confidence enough
# [42770.0] - Factor 1.80037522315979 - Bet 0.07704034321426644 - Position bear
# current price: 414.0
# ema9 : [414.3]  ema21: [415.]
# bet bearish , confidence enough
# [42772.0] - Factor 2.005774974822998 - Bet 0.012410412723721865 - Position bear
# current price: 414.2
# ema9 : [414.1]  ema21: [414.9]
# bet bearish , confidence 100
# [42774.0] - Factor 2.271282911300659 - Bet 0.01 - Position bear
# current price: 413.7
# ema9 : [414.1]  ema21: [414.7]
# bet bearish , confidence enough
# [42776.0] - Factor 0 - Bet 0.012170433375885172 - Position bear
# current price: 413.8
# ema9 : [413.9]  ema21: [414.5]
# bet bearish , confidence enough
# [42778.0] - Factor 2.501882791519165 - Bet 0.017029515652491674 - Position bear
# current price: 414.0
# ema9 : [413.8]  ema21: [414.3]
# bet bearish , confidence 100
# [42780.0] - Factor 0 - Bet 0.012300487156659016 - Position bear
# current price: 414.9
# ema9 : [414.]  ema21: [414.3]
# bet bearish , confidence 100
# [42782.0] - Factor 0 - Bet 0.01843867675940409 - Position bear
# current price: 416.6
# ema9 : [414.6]  ema21: [414.3]
# bet bullish , confidence enough
# [42784.0] - Factor 2.2959253787994385 - Bet 0.03717330094197832 - Position bull
# current price: 416.6
# ema9 : [415.2]  ema21: [414.5]
# bet bullish , confidence enough
# [42786.0] - Factor 0 - Bet 0.01 - Position bull
# current price: 416.5
# ema9 : [415.7]  ema21: [414.8]
# bet bullish , confidence enough
# [42788.0] - Factor 0 - Bet 0.04215903761330802 - Position bull
# current price: 415.1
# ema9 : [416.]  ema21: [414.8]
# bet bullish , confidence 100
# [42790.0] - Factor 2.360386610031128 - Bet 0.05356752402687634 - Position bull
# current price: 415.3
# ema9 : [415.9]  ema21: [414.9]
# bet bullish , confidence 100
# [42792.0] - Factor 1.7856022119522095 - Bet 0.01707643823042132 - Position bull
# current price: 416.2
# ema9 : [415.8]  ema21: [415.1]
# bet bullish , confidence enough
# [42794.0] - Factor 2.1071524620056152 - Bet 0.011023505329954228 - Position bull
# current price: 416.2
# ema9 : [415.8]  ema21: [415.3]
# bet bullish , confidence enough
# [42796.0] - Factor 1.6604148149490356 - Bet 0.021719544365893007 - Position bull
# current price: 416.8
# ema9 : [416.]  ema21: [415.6]
# bet bullish , confidence enough
# [42798.0] - Factor 1.6355805397033691 - Bet 0.022957866774328373 - Position bull
# current price: 416.6
# ema9 : [416.3]  ema21: [415.9]
# bet bullish , confidence enough
# [42800.0] - Factor 1.9373242855072021 - Bet 0.013562553406363176 - Position bull
# current price: 416.9
# ema9 : [416.6]  ema21: [416.2]
# bet bullish , confidence enough
# [42802.0] - Factor 1.7235406637191772 - Bet 0.019100713073481365 - Position bull
# current price: 417.7
# ema9 : [416.8]  ema21: [416.3]
# bet bullish , confidence enough
# [42804.0] - Factor 0 - Bet 0.012953931911298126 - Position bull
# current price: 417.4
# ema9 : [417.1]  ema21: [416.4]
# bet bullish , confidence enough
# [42806.0] - Factor 1.8141276836395264 - Bet 0.03737648134548411 - Position bull
# current price: 417.9
# ema9 : [417.3]  ema21: [416.6]
# bet bullish , confidence enough
# [42808.0] - Factor 1.6874889135360718 - Bet 0.020513287015008288 - Position bull
# current price: 419.7
# ema9 : [417.9]  ema21: [416.9]
# bet bullish , confidence enough
# [42810.0] - Factor 0 - Bet 0.0199623797810694 - Position bull
# current price: 418.4
# ema9 : [418.2]  ema21: [417.2]
# bet bullish , confidence enough
# [42812.0] - Factor 1.8747155666351318 - Bet 0.044407423309491025 - Position bull
# current price: 417.9
# ema9 : [418.4]  ema21: [417.5]
# bet bullish , confidence 100
# [42814.0] - Factor 0 - Bet 0.01845475142846759 - Position bull
# current price: 417.2
# ema9 : [418.3]  ema21: [417.6]
# bet bullish , confidence 100
# [42816.0] - Factor 1.9702938795089722 - Bet 0.03694012400384931 - Position bull
# current price: 417.2
# ema9 : [418.1]  ema21: [417.7]
# bet bullish , confidence 100
# [42818.0] - Factor 1.7386802434921265 - Bet 0.018563888542064495 - Position bull
# current price: 417.3
# ema9 : [417.7]  ema21: [417.7]
# do nothing
# [42820.0] - Skipped.
# current price: 417.1
# ema9 : [417.4]  ema21: [417.8]
# bet bearish , confidence enough
# [42822.0] - Factor 2.3768270015716553 - Bet 0.01 - Position bear
# current price: 416.5
# ema9 : [417.1]  ema21: [417.7]
# bet bearish , confidence enough
# [42824.0] - Factor 2.44590425491333 - Bet 0.01 - Position bear
# current price: 416.0
# ema9 : [416.8]  ema21: [417.6]
# bet bearish , confidence enough
# [42826.0] - Factor 2.505707263946533 - Bet 0.01 - Position bear
# current price: 416.3
# ema9 : [416.5]  ema21: [417.4]
# bet bearish , confidence enough
# [42828.0] - Factor 0 - Bet 0.012027722435656921 - Position bear
# current price: 415.9
# ema9 : [416.3]  ema21: [417.2]
# bet bearish , confidence enough
# [42830.0] - Factor 0 - Bet 0.044430947085725564 - Position bear
# current price: 416.1
# ema9 : [416.2]  ema21: [417.]
# bet bearish , confidence enough
# [42832.0] - Factor 0 - Bet 0.08460972729088248 - Position bear
# current price: 417.6
# ema9 : [416.5]  ema21: [416.8]
# bet bearish , confidence 100
# [42834.0] - Factor 2.128988742828369 - Bet 0.16261596061145692 - Position bear
# current price: 417.3
# ema9 : [416.7]  ema21: [416.8]
# bet bearish , confidence 100
# [42836.0] - Factor 1.8268951177597046 - Bet 0.015951631647310265 - Position bear
# current price: 417.6
# ema9 : [416.9]  ema21: [416.8]
# bet bullish , confidence enough
# [42838.0] - Factor 0 - Bet 0.018874886304377916 - Position bull
# current price: 416.6
# ema9 : [417.1]  ema21: [416.7]
# bet bullish , confidence 100
# [42840.0] - Factor 0 - Bet 0.03276431441641062 - Position bull
# current price: 415.0
# ema9 : [416.9]  ema21: [416.6]
# bet bullish , confidence 100
# [42842.0] - Factor 2.184023380279541 - Bet 0.06263997579333744 - Position bull
# current price: 416.1
# ema9 : [416.5]  ema21: [416.5]
# do nothing
# [42844.0] - Skipped.
# current price: 417.5
# ema9 : [416.4]  ema21: [416.5]
# bet bearish , confidence 100
# [42846.0] - Factor 1.6876072883605957 - Bet 0.020508307071498883 - Position bear
# current price: 415.4
# ema9 : [415.9]  ema21: [416.5]
# bet bearish , confidence enough
# [42848.0] - Factor 0 - Bet 0.014217585906180157 - Position bear
# current price: 416.6
# ema9 : [415.9]  ema21: [416.5]
# bet bearish , confidence 100
# [42850.0] - Factor 0 - Bet 0.020222011781365082 - Position bear
# current price: 416.8
# ema9 : [416.3]  ema21: [416.5]
# bet bearish , confidence 100
# [42852.0] - Factor 0 - Bet 0.04690971511051964 - Position bear
# current price: 416.9
# ema9 : [416.6]  ema21: [416.6]
# do nothing
# [42854.0] - Skipped.
# current price: 417.2
# ema9 : [416.7]  ema21: [416.6]
# bet bullish , confidence enough
# [42856.0] - Factor 1.775312066078186 - Bet 0.15878219523671577 - Position bull
# current price: 417.4
# ema9 : [417.]  ema21: [416.6]
# bet bullish , confidence enough
# [42858.0] - Factor 2.5023550987243652 - Bet 0.01 - Position bull
# current price: 417.7
# ema9 : [417.2]  ema21: [416.6]
# bet bullish , confidence enough
# [42860.0] - Factor 0 - Bet 0.012114278874864352 - Position bull
# current price: 420.2
# ema9 : [417.7]  ema21: [416.8]
# bet bullish , confidence enough
# [42862.0] - Factor 0 - Bet 0.10886126221961401 - Position bull
# current price: 414.6
# ema9 : [417.4]  ema21: [416.9]
# bet bullish , confidence 100
# [42864.0] - Factor 0 - Bet 0.057279826312101816 - Position bull
# current price: 412.1
# ema9 : [416.4]  ema21: [416.6]
# bet bearish , confidence enough
# [42866.0] - Factor 3.242083787918091 - Bet 0.09218787618822781 - Position bear
# current price: 409.0
# ema9 : [414.8]  ema21: [416.]
# bet bearish , confidence enough
# [42868.0] - Factor 0 - Bet 0.020275628005834934 - Position bear
# current price: 409.6
# ema9 : [413.]  ema21: [415.4]
# bet bearish , confidence enough
# [42870.0] - Factor 2.169656991958618 - Bet 0.031223028614150394 - Position bear
# current price: 408.6
# ema9 : [410.7]  ema21: [414.6]
# bet bearish , confidence enough
# [42872.0] - Factor 0 - Bet 0.01 - Position bear
# current price: 409.7
# ema9 : [409.6]  ema21: [413.9]
# bet bearish , confidence 100
# [42874.0] - Factor 0 - Bet 0.01 - Position bear
# current price: 409.4
# ema9 : [409.2]  ema21: [413.2]
# bet bearish , confidence 100
# [42876.0] - Factor 0 - Bet 0.03168628310525832 - Position bear
# current price: 411.0
# ema9 : [409.6]  ema21: [412.6]
# bet bearish , confidence 100
# [42878.0] - Factor 2.1081621646881104 - Bet 0.06792430416482192 - Position bear
# current price: 410.1
# ema9 : [409.9]  ema21: [411.9]
# bet bearish , confidence 100
# [42880.0] - Factor 1.8092141151428223 - Bet 0.01641459012757055 - Position bear
# current price: 410.0
# ema9 : [410.2]  ema21: [411.1]
# bet bearish , confidence enough
# [42882.0] - Factor 0 - Bet 0.01 - Position bear
# current price: 411.5
# ema9 : [410.5]  ema21: [410.4]
# bet bullish , confidence enough
# [42884.0] - Factor 1.7299628257751465 - Bet 0.03773849603648546 - Position bull
# current price: 412.8
# ema9 : [410.9]  ema21: [410.2]
# bet bullish , confidence enough
# [42886.0] - Factor 1.635737419128418 - Bet 0.022949601207081227 - Position bull
# current price: 412.3
# ema9 : [411.3]  ema21: [410.3]
# bet bullish , confidence enough
# [42888.0] - Factor 2.141197443008423 - Bet 0.010624763246313356 - Position bull
# current price: 413.0
# ema9 : [412.]  ema21: [410.7]
# bet bullish , confidence enough
# [42890.0] - Factor 1.8235752582550049 - Bet 0.016036556722894543 - Position bull
# current price: 413.5
# ema9 : [412.7]  ema21: [411.1]
# bet bullish , confidence enough
# [42892.0] - Factor 1.7725142240524292 - Bet 0.017466814936434188 - Position bull
# current price: 414.3
# ema9 : [413.3]  ema21: [411.7]
# bet bullish , confidence enough
# [42894.0] - Factor 1.9160943031311035 - Bet 0.013964641188004516 - Position bull
# current price: 414.5
# ema9 : [413.6]  ema21: [412.1]
# bet bullish , confidence enough
# [42896.0] - Factor 0 - Bet 0.020927157565035756 - Position bull
# current price: 414.6
# ema9 : [414.]  ema21: [412.5]
# bet bullish , confidence enough
# [42898.0] - Factor 0 - Bet 0.04141934524306503 - Position bull
# current price: 414.2
# ema9 : [414.3]  ema21: [412.8]
# bet bullish , confidence 100
# [42900.0] - Factor 1.802435278892517 - Bet 0.12009008327184706 - Position bull
# current price: 414.0
# ema9 : [414.3]  ema21: [413.2]
# bet bullish , confidence 100
# [42902.0] - Factor 2.328382730484009 - Bet 0.01 - Position bull
# current price: 414.2
# ema9 : [414.3]  ema21: [413.6]
# bet bullish , confidence 100
# [42904.0] - Factor 2.0571868419647217 - Bet 0.011666068015089246 - Position bull
# current price: 414.3
# ema9 : [414.3]  ema21: [413.9]
# bet bullish , confidence 100
# [42906.0] - Factor 0 - Bet 0.010697661416877799 - Position bull
# current price: 413.6
# ema9 : [414.2]  ema21: [414.]
# bet bullish , confidence 100
# [42908.0] - Factor 0 - Bet 0.01835907478269172 - Position bull
# current price: 413.6
# ema9 : [414.]  ema21: [414.1]
# bet bearish , confidence enough
# [42910.0] - Factor 0 - Bet 0.06184653064241059 - Position bear
# current price: 413.7
# ema9 : [413.9]  ema21: [414.1]
# bet bearish , confidence enough
# [42912.0] - Factor 2.2705183029174805 - Bet 0.09425646116183976 - Position bear
# current price: 412.0
# ema9 : [413.4]  ema21: [414.]
# bet bearish , confidence enough
# [42914.0] - Factor 0 - Bet 0.01 - Position bear
# current price: 412.5
# ema9 : [413.1]  ema21: [413.8]
# bet bearish , confidence enough
# [42916.0] - Factor 0 - Bet 0.023343966108398204 - Position bear
# current price: 412.9
# ema9 : [412.9]  ema21: [413.6]
# bet bearish , confidence enough
# [42918.0] - Factor 0 - Bet 0.05947175752822367 - Position bear
# current price: 413.3
# ema9 : [412.8]  ema21: [413.5]
# bet bearish , confidence 100
# [42920.0] - Factor 2.136029005050659 - Bet 0.10984245475497562 - Position bear
# current price: 412.8
# ema9 : [412.8]  ema21: [413.4]
# bet bearish , confidence enough
# [42922.0] - Factor 2.5820746421813965 - Bet 0.01 - Position bear
# current price: 413.2
# ema9 : [412.9]  ema21: [413.3]
# bet bearish , confidence 100
# [42924.0] - Factor 0 - Bet 0.01 - Position bear
# current price: 413.9
# ema9 : [413.2]  ema21: [413.2]
# do nothing
# [42926.0] - Skipped.
# current price: 414.4
# ema9 : [413.5]  ema21: [413.2]
# bet bullish , confidence enough
# [42928.0] - Factor 0 - Bet 0.011717500422053667 - Position bull
# current price: 413.0
# ema9 : [413.5]  ema21: [413.2]
# bet bullish , confidence 100
# [42930.0] - Factor 0 - Bet 0.06200675496589788 - Position bull
# current price: 413.4
# ema9 : [413.6]  ema21: [413.2]
# bet bullish , confidence 100
# [42932.0] - Factor 1.6606210470199585 - Bet 0.20347367102374395 - Position bull
# current price: 413.6
# ema9 : [413.7]  ema21: [413.2]
# bet bullish , confidence 100
# [42934.0] - Factor 0 - Bet 0.01 - Position bull
# current price: 411.3
# ema9 : [413.2]  ema21: [413.2]
# do nothing
# [42936.0] - Skipped.
# current price: 411.8
# ema9 : [412.7]  ema21: [413.1]
# bet bearish , confidence enough
# [42938.0] - Factor 2.6261110305786133 - Bet 0.014024153499384576 - Position bear
# current price: 411.2
# ema9 : [412.3]  ema21: [412.9]
# bet bearish , confidence enough
# [42940.0] - Factor 0 - Bet 0.02093885852153518 - Position bear
# current price: 412.0
# ema9 : [411.9]  ema21: [412.8]
# bet bearish , confidence 100
# [42942.0] - Factor 0 - Bet 0.030771336365573488 - Position bear
# current price: 412.8
# ema9 : [411.8]  ema21: [412.8]
# bet bearish , confidence 100
# [42944.0] - Factor 2.06817626953125 - Bet 0.07108025991130526 - Position bear
# current price: 412.6
# ema9 : [412.1]  ema21: [412.7]
# bet bearish , confidence 100
# [42946.0] - Factor 1.9412599802017212 - Bet 0.01349054348958468 - Position bear
# current price: 412.7
# ema9 : [412.3]  ema21: [412.6]
# bet bearish , confidence 100
# [42948.0] - Factor 2.2749547958374023 - Bet 0.01 - Position bear
# current price: 411.7
# ema9 : [412.4]  ema21: [412.4]
# do nothing
# [42950.0] - Skipped.
# current price: 412.2
# ema9 : [412.4]  ema21: [412.3]
# bet bullish , confidence 100
# [42952.0] - Factor 1.908059000968933 - Bet 0.01412311683957925 - Position bull
# current price: 412.2
# ema9 : [412.2]  ema21: [412.1]
# bet bullish , confidence enough
# [42954.0] - Factor 0 - Bet 0.01 - Position bull
# current price: 412.1
# ema9 : [412.1]  ema21: [412.]
# bet bullish , confidence enough
# [42956.0] - Factor 1.767972469329834 - Bet 0.03521297436053289 - Position bull
# current price: 412.5
# ema9 : [412.1]  ema21: [412.1]
# do nothing
# [42958.0] - Skipped.
# current price: 411.6
# ema9 : [412.]  ema21: [412.1]
# bet bearish , confidence enough
# [42960.0] - Factor 0 - Bet 0.01857702342005762 - Position bear
# current price: 412.7
# ema9 : [412.1]  ema21: [412.3]
# bet bearish , confidence 100
# [42962.0] - Factor 0 - Bet 0.016979938016778072 - Position bear
# current price: 415.2
# ema9 : [412.7]  ema21: [412.5]
# bet bullish , confidence enough
# [42964.0] - Factor 1.7896043062210083 - Bet 0.07726700934195524 - Position bull
# current price: 417.3
# ema9 : [413.9]  ema21: [412.9]
# bet bullish , confidence enough
# [42966.0] - Factor 0 - Bet 0.01 - Position bull
# current price: 417.8
# ema9 : [415.1]  ema21: [413.4]
# bet bullish , confidence enough
# [42968.0] - Factor 2.3923990726470947 - Bet 0.016772908046297393 - Position bull
# current price: 418.6
# ema9 : [416.5]  ema21: [413.9]
# bet bullish , confidence enough
# [42970.0] - Factor 2.061237096786499 - Bet 0.011611204437561522 - Position bull
# current price: 419.8
# ema9 : [417.8]  ema21: [414.7]
# bet bullish , confidence enough
# [42972.0] - Factor 0 - Bet 0.019285236295071603 - Position bull
# current price: 419.2
# ema9 : [418.5]  ema21: [415.4]
# bet bullish , confidence enough
# [42974.0] - Factor 0 - Bet 0.039791676636366805 - Position bull
# current price: 415.3
# ema9 : [418.4]  ema21: [415.8]
# bet bullish , confidence 100
# [42976.0] - Factor 2.3132755756378174 - Bet 0.06204835033038689 - Position bull
# current price: 414.1
# ema9 : [417.7]  ema21: [416.]
# bet bullish , confidence 100
# [42978.0] - Factor 1.8288726806640625 - Bet 0.015901469896005705 - Position bull
# current price: 414.8
# ema9 : [416.9]  ema21: [416.3]
# bet bullish , confidence 100
# [42980.0] - Factor 1.9630407094955444 - Bet 0.013105460659643077 - Position bull
# current price: 414.1
# ema9 : [415.7]  ema21: [416.6]
# bet bearish , confidence enough
# [42982.0] - Factor 0 - Bet 0.01 - Position bear
# current price: 415.8
# ema9 : [415.1]  ema21: [416.8]
# bet bearish , confidence 100
# [42984.0] - Factor 1.7157940864562988 - Bet 0.03877516343277138 - Position bear
# current price: 414.2
# ema9 : [414.9]  ema21: [416.6]
# bet bearish , confidence enough
# [42986.0] - Factor 0 - Bet 0.013805489420475447 - Position bear
# current price: 415.5
# ema9 : [415.1]  ema21: [416.5]
# bet bearish , confidence 100
# [42988.0] - Factor 0 - Bet 0.035918042294312925 - Position bear
# current price: 415.9
# ema9 : [415.3]  ema21: [416.3]
# bet bearish , confidence 100
# [42990.0] - Factor 0 - Bet 0.0750179409040701 - Position bear
# current price: 417.8
# ema9 : [415.8]  ema21: [416.1]
# bet bearish , confidence 100
# [42992.0] - Factor 0 - Bet 0.10898179488562768 - Position bear
# current price: 418.6
# ema9 : [416.5]  ema21: [416.]
# bet bullish , confidence enough
# [42994.0] - Factor 0 - Bet 0.37781056026872856 - Position bull
# current price: 419.2
# ema9 : [417.4]  ema21: [416.]
# bet bullish , confidence enough
# [42996.0] - Factor 1.4886505603790283 - Bet 2.1532396367326494 - Position bull
# current price: 418.5
# ema9 : [418.1]  ema21: [416.4]
# bet bullish , confidence enough
# [42998.0] - Factor 1.972563624382019 - Bet 0.012943917736224112 - Position bull
# current price: 419.1
# ema9 : [418.6]  ema21: [416.7]
# bet bullish , confidence enough
# [43000.0] - Factor 1.5057361125946045 - Bet 0.032707945146341455 - Position bull
# current price: 420.9
# ema9 : [419.1]  ema21: [417.3]
# bet bullish , confidence enough
# [43002.0] - Factor 1.4053393602371216 - Bet 0.04869986927227302 - Position bull
# current price: 422.0
# ema9 : [419.8]  ema21: [417.9]
# bet bullish , confidence enough
# [43004.0] - Factor 1.7731364965438843 - Bet 0.017447850660884084 - Position bull
# current price: 422.3
# ema9 : [420.6]  ema21: [418.6]
# bet bullish , confidence enough
# [43006.0] - Factor 0 - Bet 0.01 - Position bull
# current price: 422.5
# ema9 : [421.4]  ema21: [419.3]
# bet bullish , confidence enough
# [43008.0] - Factor 1.570326328277588 - Bet 0.05400642210080313 - Position bull
# current price: 423.5
# ema9 : [422.3]  ema21: [420.1]
# bet bullish , confidence enough
# [43010.0] - Factor 2.103855848312378 - Bet 0.011063711120165192 - Position bull
# current price: 423.6
# ema9 : [423.]  ema21: [420.8]
# bet bullish , confidence enough
# [43012.0] - Factor 1.7704201936721802 - Bet 0.01753093616062791 - Position bull
# current price: 425.6
# ema9 : [423.6]  ema21: [421.5]
# bet bullish , confidence enough
# [43014.0] - Factor 1.4037175178527832 - Bet 0.049087580220894475 - Position bull
# current price: 426.8
# ema9 : [424.6]  ema21: [422.2]
# bet bullish , confidence enough
# [43016.0] - Factor 0 - Bet 0.02430585560609797 - Position bull
# current price: 427.2
# ema9 : [425.5]  ema21: [423.]
# bet bullish , confidence enough
# [43018.0] - Factor 1.6217961311340332 - Bet 0.08133278869548634 - Position bull
# current price: 426.6
# ema9 : [426.2]  ema21: [423.8]
# bet bullish , confidence enough
# [43020.0] - Factor 0 - Bet 0.01 - Position bull
# current price: 425.3
# ema9 : [426.4]  ema21: [424.4]
# bet bullish , confidence 100
# [43022.0] - Factor 1.5185775756835938 - Bet 0.06277905768189938 - Position bull
# current price: 427.5
# ema9 : [426.6]  ema21: [424.9]
# bet bullish , confidence enough
# [43024.0] - Factor 0 - Bet 0.0206695920347906 - Position bull
# current price: 426.7
# ema9 : [426.6]  ema21: [425.3]
# bet bullish , confidence enough
# [43026.0] - Factor 0 - Bet 0.04399266356278106 - Position bull
# current price: 427.2
# ema9 : [426.5]  ema21: [425.8]
# bet bullish , confidence enough
# [43028.0] - Factor 0 - Bet 0.1138753659428438 - Position bull
# current price: 427.7
# ema9 : [426.8]  ema21: [426.2]
# bet bullish , confidence enough
# [43030.0] - Factor 1.857237458229065 - Bet 0.2868637798710265 - Position bull

# %% [markdown]
# ## Overview

# %%
sum_reward = 0
df_running = df_running.reset_index(drop=True)

for index, row in df_running.iterrows():
        reward = row["reward"]
        sum_reward += reward
        
        df_running.loc[df_running.index == index, "acc_reward"] = sum_reward
        
df_running
# Out:
#        epoch position    amount    reward  recent_loss    factor  acc_reward
# 0    42754.0     bear  0.014678 -0.014678     0.000000  1.681278   -0.014678
# 1    42756.0     bear  0.030849 -0.030849     0.014678  1.799963   -0.045528
# 2    42760.0     bull  0.055278 -0.055278     0.045528  2.004518   -0.100805
# 3    42762.0     bull  0.125438  0.135893     0.100805  1.883345    0.035088
# 4    42764.0     bull  0.013181 -0.013181     0.000000  1.758639    0.021906
# 5    42768.0     bear  0.023072 -0.023072     0.013181  2.004762   -0.001165
# 6    42770.0     bear  0.077040  0.061661     0.036253  1.600375    0.060496
# 7    42772.0     bear  0.012410  0.012482     0.000000  1.805775    0.072978
# 8    42774.0     bear  0.010000  0.012713     0.000000  2.071283    0.085691
# 9    42776.0     bear  0.012170  -0.01217     0.000000  1.821663    0.073520
# 10   42778.0     bear  0.017030  0.025576     0.012170  2.301883    0.099097
# 11   42780.0     bear  0.012300   -0.0123     0.000000  1.812976    0.086796
# 12   42782.0     bear  0.018439 -0.018439     0.012300  2.209441    0.068357
# 13   42784.0     bull  0.037173  0.048174     0.030739  2.095925    0.116531
# 14   42786.0     bull  0.010000     -0.01     0.000000  2.063317    0.106531
# 15   42788.0     bull  0.042159 -0.042159     0.010000  1.474394    0.064372
# 16   42790.0     bull  0.053568  0.072873     0.052159  2.160387    0.137245
# 17   42792.0     bull  0.017076  0.013415     0.000000  1.585602    0.150660
# 18   42794.0     bull  0.011024  0.012205     0.000000  1.907152    0.162865
# 19   42796.0     bull  0.021720  0.014344     0.000000  1.460415    0.177209
# 20   42798.0     bull  0.022958  0.014592     0.000000  1.435581    0.191800
# 21   42800.0     bull  0.013563  0.012713     0.000000  1.737324    0.204513
# 22   42802.0     bull  0.019101   0.01382     0.000000  1.523541    0.218333
# 23   42804.0     bull  0.012954 -0.012954     0.000000  1.771966    0.205379
# 24   42806.0     bull  0.037376  0.030429     0.012954  1.614128    0.235808
# 25   42808.0     bull  0.020513  0.014103     0.000000  1.487489    0.249911
# 26   42810.0     bull  0.019962 -0.019962     0.000000  1.500942    0.229948
# 27   42812.0     bull  0.044407  0.038844     0.019962  1.674716    0.268792
# 28   42814.0     bull  0.018455 -0.018455     0.000000  1.541866    0.250338
# 29   42816.0     bull  0.036940  0.035843     0.018455  1.770294    0.286180
# 30   42818.0     bull  0.018564  0.013713     0.000000  1.538680    0.299893
# 31   42822.0     bear  0.010000  0.013768     0.000000  2.176827    0.313661
# 32   42824.0     bear  0.010000  0.014459     0.000000  2.245904    0.328120
# 33   42826.0     bear  0.010000  0.015057     0.000000  2.305707    0.343177
# 34   42828.0     bear  0.012028 -0.012028     0.000000  1.831413    0.331150
# 35   42830.0     bear  0.044431 -0.044431     0.012028  1.495774    0.286719
# 36   42832.0     bear  0.084610  -0.08461     0.056459  1.785473    0.202109
# 37   42834.0     bear  0.162616  0.183592     0.141068  1.928989    0.385701
# 38   42836.0     bear  0.015952   0.01319     0.000000  1.626895    0.398891
# 39   42838.0     bull  0.018875 -0.018875     0.000000  1.529805    0.380016
# 40   42840.0     bull  0.032764 -0.032764     0.018875  1.881291    0.347252
# 41   42842.0     bull  0.062640  0.074167     0.051639  1.984023    0.421419
# 42   42846.0     bear  0.020508  0.014102     0.000000  1.487607    0.435521
# 43   42848.0     bear  0.014218 -0.014218     0.000000  1.703354    0.421303
# 44   42850.0     bear  0.020222 -0.020222     0.014218  2.197585    0.401081
# 45   42852.0     bear  0.046910  -0.04691     0.034440  1.947343    0.354171
# 46   42856.0     bull  0.158782  0.123106     0.081349  1.575312    0.477277
# 47   42858.0     bull  0.010000  0.015024     0.000000  2.302355    0.492301
# 48   42860.0     bull  0.012114 -0.012114     0.000000  1.825472    0.480186
# 49   42862.0     bull  0.108861 -0.108861     0.012114  1.203142    0.371325
# 50   42864.0     bull  0.057280  -0.05728     0.120976  3.286591    0.314045
# 51   42866.0     bear  0.092188  0.206693     0.178255  3.042084    0.520738
# 52   42868.0     bear  0.020276 -0.020276     0.000000  1.493203    0.500463
# 53   42870.0     bear  0.031223   0.03652     0.020276  1.969657    0.536983
# 54   42872.0     bear  0.010000     -0.01     0.000000  2.167476    0.526983
# 55   42874.0     bear  0.010000     -0.01     0.010000  3.621623    0.516983
# 56   42876.0     bear  0.031686 -0.031686     0.020000  1.946782    0.485297
# 57   42878.0     bear  0.067924  0.075271     0.051686  1.908162    0.560568
# 58   42880.0     bear  0.016415  0.013283     0.000000  1.609214    0.573851
# 59   42882.0     bear  0.010000     -0.01     0.000000  3.204371    0.563851
# 60   42884.0     bull  0.037738  0.027548     0.010000  1.529963    0.591398
# 61   42886.0     bull  0.022950   0.01459     0.000000  1.435737    0.605988
# 62   42888.0     bull  0.010625  0.012125     0.000000  1.941197    0.618113
# 63   42890.0     bull  0.016037  0.013207     0.000000  1.623575    0.631320
# 64   42892.0     bull  0.017467  0.013493     0.000000  1.572514    0.644814
# 65   42894.0     bull  0.013965  0.012793     0.000000  1.716094    0.657607
# 66   42896.0     bull  0.020927 -0.020927     0.000000  1.477848    0.636680
# 67   42898.0     bull  0.041419 -0.041419     0.020927  1.746684    0.595260
# 68   42900.0     bull  0.120090  0.096365     0.062347  1.602435    0.691625
# 69   42902.0     bull  0.010000  0.013284     0.000000  2.128383    0.704909
# 70   42904.0     bull  0.011666  0.012333     0.000000  1.857187    0.717242
# 71   42906.0     bull  0.010698 -0.010698     0.000000  1.934784    0.706544
# 72   42908.0     bull  0.018359 -0.018359     0.010698  2.127380    0.688185
# 73   42910.0     bear  0.061847 -0.061847     0.029057  1.631511    0.626339
# 74   42912.0     bear  0.094256  0.119755     0.090903  2.070518    0.746093
# 75   42914.0     bear  0.010000     -0.01     0.000000  2.240002    0.736093
# 76   42916.0     bear  0.023344 -0.023344     0.010000  1.856752    0.712749
# 77   42918.0     bear  0.059472 -0.059472     0.033344  1.728816    0.653277
# 78   42920.0     bear  0.109842  0.124784     0.092816  1.936029    0.778062
# 79   42922.0     bear  0.010000  0.015821     0.000000  2.382075    0.793882
# 80   42924.0     bear  0.010000     -0.01     0.000000  2.135691    0.783882
# 81   42928.0     bull  0.011718 -0.011718     0.010000  2.706849    0.772165
# 82   42930.0     bull  0.062007 -0.062007     0.021718  1.511517    0.710158
# 83   42932.0     bull  0.203474  0.134419     0.083724  1.460621    0.844577
# 84   42934.0     bull  0.010000     -0.01     0.000000  2.201154    0.834577
# 85   42938.0     bear  0.014024  0.022805     0.010000  2.426111    0.857382
# 86   42940.0     bear  0.020939 -0.020939     0.000000  1.477581    0.836443
# 87   42942.0     bear  0.030771 -0.030771     0.020939  2.005444    0.805672
# 88   42944.0     bear  0.071080  0.075926     0.051710  1.868176    0.881598
# 89   42946.0     bear  0.013491  0.012698     0.000000  1.741260    0.894296
# 90   42948.0     bear  0.010000   0.01275     0.000000  2.074955    0.907046
# 91   42952.0     bull  0.014123  0.012825     0.000000  1.708059    0.919870
# 92   42954.0     bull  0.010000     -0.01     0.000000  2.042878    0.909870
# 93   42956.0     bull  0.035213  0.027043     0.010000  1.567972    0.936913
# 94   42960.0     bear  0.018577 -0.018577     0.000000  1.538299    0.918336
# 95   42962.0     bear  0.016980  -0.01698     0.018577  2.682987    0.901356
# 96   42964.0     bull  0.077267   0.06101     0.035557  1.589604    0.962366
# 97   42966.0     bull  0.010000     -0.01     0.000000  2.749909    0.952366
# 98   42968.0     bull  0.016773  0.023355     0.010000  2.192399    0.975721
# 99   42970.0     bull  0.011611  0.012322     0.000000  1.861237    0.988043
# 100  42972.0     bull  0.019285 -0.019285     0.000000  1.518531    0.968758
# 101  42974.0     bull  0.039792 -0.039792     0.019285  1.735964    0.928966
# 102  42976.0     bull  0.062048  0.081487     0.059077  2.113276    1.010453
# 103  42978.0     bull  0.015901   0.01318     0.000000  1.628873    1.023633
# 104  42980.0     bull  0.013105  0.012621     0.000000  1.763041    1.036254
# 105  42982.0     bear  0.010000     -0.01     0.000000  2.128609    1.026254
# 106  42984.0     bear  0.038775  0.027755     0.010000  1.515794    1.054009
# 107  42986.0     bear  0.013805 -0.013805     0.000000  1.724350    1.040204
# 108  42988.0     bear  0.035918 -0.035918     0.013805  1.662772    1.004286
# 109  42990.0     bear  0.075018 -0.075018     0.049724  1.796123    0.929268
# 110  42992.0     bear  0.108982 -0.108982     0.124741  2.236367    0.820286
# 111  42994.0     bull  0.377811 -0.377811     0.233723  1.645094    0.442475
# 112  42996.0     bull  2.153240  1.052182     0.611534  1.288651    1.494657
# 113  42998.0     bull  0.012944  0.012589     0.000000  1.772564    1.507246
# 114  43000.0     bull  0.032708  0.016542     0.000000  1.305736    1.523787
# 115  43002.0     bull  0.048700   0.01974     0.000000  1.205339    1.543527
# 116  43004.0     bull  0.017448   0.01349     0.000000  1.573136    1.557017
# 117  43006.0     bull  0.010000     -0.01     0.000000  2.479995    1.547017
# 118  43008.0     bull  0.054006  0.030801     0.010000  1.370326    1.577818
# 119  43010.0     bull  0.011064  0.012213     0.000000  1.903856    1.590031
# 120  43012.0     bull  0.017531  0.013506     0.000000  1.570420    1.603537
# 121  43014.0     bull  0.049088  0.019818     0.000000  1.203718    1.623355
# 122  43016.0     bull  0.024306 -0.024306     0.000000  1.411423    1.599049
# 123  43018.0     bull  0.081333  0.050572     0.024306  1.421796    1.649621
# 124  43020.0     bull  0.010000     -0.01     0.000000  4.591319    1.639621
# 125  43022.0     bull  0.062779  0.032556     0.010000  1.318578    1.672177
# 126  43024.0     bull  0.020670  -0.02067     0.000000  1.483802    1.651508
# 127  43026.0     bull  0.043993 -0.043993     0.020670  1.697152    1.607515
# 128  43028.0     bull  0.113875 -0.113875     0.064662  1.655649    1.493640
# 129  43030.0     bull  0.286864   0.24591     0.178538  1.657237    1.739550

# %%
summary = overview(df_running)
print(summary)
# Out:
# {'total_spent': 7.331658578880165, 'max_spent': 2.1532396367326494, 'total_loss': 2.168283608912439, 'loss_times': 61, 'estimated_win': 3.907833489895577, 'win_times': 69, 'estimated_gain': 1.739549880983139, 'recent_loss': 0.0, 'recent_loss_times': 0}

# %% [markdown]
# ### Counting Consecutive Win/Loss

# %%
def add_result_binary(reward):
    if reward > 0:
        # bull
        return 1
    else:
        # bear
        return -1
        
temp_df = df_running.copy()

temp_df["result"] = temp_df.apply(lambda row : add_result_binary(row["reward"]), axis=1)

countDf = pd.DataFrame({'result': list(temp_df['result'][(temp_df['result'])
                       .diff().abs().fillna(1) > 0]),
                     'runs': list(temp_df['result'].groupby((temp_df['result'])
                       .diff().abs().fillna(1).cumsum()).count())})

loss_count = countDf[countDf.result == -1]['runs'].max()
win_count = countDf[countDf.result == 1]['runs'].max()

print(f"Loss {loss_count} / Win {win_count}")
# Out:
# Loss 5 / Win 7
